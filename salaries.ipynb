# %%
import pandas as pd 
df=pd.read_csv(r"C:\Users\apano\OneDrive\Documents\power BI FEB 25\excel sheets\Salaries (1).csv", encoding='cp1252')
df
# Out:
# C:\Users\apano\AppData\Local\Temp\ipykernel_19548\3983767698.py:2: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(r"C:\Users\apano\OneDrive\Documents\power BI FEB 25\excel sheets\Salaries (1).csv", encoding='cp1252')
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# ...

# %%
df.describe()
# Out:
#                   Id       TotalPay  TotalPayBenefits           Year  Notes
# count  148654.000000  148654.000000     148654.000000  148654.000000    0.0
# mean    74327.500000   74768.321972      93692.554811    2012.522643    NaN
# std     42912.857795   50517.005274      62793.533483       1.117538    NaN
# min         1.000000    -618.130000       -618.130000    2011.000000    NaN
# 25%     37164.250000   36168.995000      44065.650000    2012.000000    NaN
# 50%     74327.500000   71426.610000      92404.090000    2013.000000    NaN
# 75%    111490.750000  105839.135000     132876.450000    2014.000000    NaN
# max    148654.000000  567595.430000     567595.430000    2014.000000    NaN

# %%
if df is not None:
    df.drop_duplicates(inplace=True)
else:
    print("DataFrame is None. Check your data loading step.")
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC       77916.0
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# ...

# %%
df.drop(columns=['Notes'], inplace=True)
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC       77916.0
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# ...

# %%
pd.set_option('display.max_columns', None)
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC       77916.0
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# ...

# %%
df['EmployeeName'] = df['EmployeeName'].str.upper()
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      ROY I TILLERY
# 148650  148651       NOT PROVIDED
# 148651  148652       NOT PROVIDED
# 148652  148653       NOT PROVIDED
# 148653  148654          JOE LOPEZ
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC       77916.0
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# ...

# %%
df['JobTitle'] = df['JobTitle'].str.upper()
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      ROY I TILLERY
# 148650  148651       NOT PROVIDED
# 148651  148652       NOT PROVIDED
# 148652  148653       NOT PROVIDED
# 148653  148654          JOE LOPEZ
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC       77916.0
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# ...

# %%
df['Benefits'].fillna(0)
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      ROY I TILLERY
# 148650  148651       NOT PROVIDED
# 148651  148652       NOT PROVIDED
# 148652  148653       NOT PROVIDED
# 148653  148654          JOE LOPEZ
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC       77916.0
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# ...

# %%
df['Agency']=df['Agency'].str.title()
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      ROY I TILLERY
# 148650  148651       NOT PROVIDED
# 148651  148652       NOT PROVIDED
# 148652  148653       NOT PROVIDED
# 148653  148654          JOE LOPEZ
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC       77916.0
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# ...

# %%
print(df['Benefits'].dtype)
# Out:
# object

# %%
df.fillna(0, inplace=True)
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      ROY I TILLERY
# 148650  148651       NOT PROVIDED
# 148651  148652       NOT PROVIDED
# 148652  148653       NOT PROVIDED
# 148653  148654          JOE LOPEZ
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC       77916.0
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# ...

# %%
df = df[~df.apply(lambda row: row.astype(str).str.contains("NOT PROVIDED", case=False)).any(axis=1)]
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148645  148646   CAROLYN A WILSON
# 148647  148648     JOANN ANDERSON
# 148648  148649        LEON WALKER
# 148649  148650      ROY I TILLERY
# 148653  148654          JOE LOPEZ
#
#                                               JobTitle    BasePay OvertimePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18         0.0
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02   245131.88
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13   106088.18
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC    77916.0    56120.71
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)   134401.6      9737.0
# ...                                                ...        ...         ...
# ...

# %%
df.to_csv(r"C:\Users\apano\OneDrive\Documents\power BI FEB 25\excel sheets\task3\salary.csv" ,index= False)

# %%
print(df['Benefits'].dtype)
# Out:
# object

# %%
df.drop(columns=['Agency'], inplace=True)
df
# Out:
# C:\Users\apano\AppData\Local\Temp\ipykernel_19548\1733012333.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['Agency'], inplace=True)
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148645  148646   CAROLYN A WILSON
# 148647  148648     JOANN ANDERSON
# 148648  148649        LEON WALKER
# 148649  148650      ROY I TILLERY
# 148653  148654          JOE LOPEZ
#
#                                               JobTitle    BasePay OvertimePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18         0.0
# ...

# %%
df['BasePay'] = pd.to_numeric(df['BasePay'], errors='coerce')
df['OvertimePay'] = pd.to_numeric(df['OvertimePay'], errors='coerce')
df['OtherPay'] = pd.to_numeric(df['OtherPay'], errors='coerce')
df['Benefits'] = pd.to_numeric(df['Benefits'], errors='coerce')
df['TotalPay'] = pd.to_numeric(df['TotalPay'], errors='coerce')
df['TotalPayBenefits'] = pd.to_numeric(df['TotalPayBenefits'], errors='coerce')
df
# Out:
# C:\Users\apano\AppData\Local\Temp\ipykernel_19548\2625706324.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['BasePay'] = pd.to_numeric(df['BasePay'], errors='coerce')
# C:\Users\apano\AppData\Local\Temp\ipykernel_19548\2625706324.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['OvertimePay'] = pd.to_numeric(df['OvertimePay'], errors='coerce')
# C:\Users\apano\AppData\Local\Temp\ipykernel_19548\2625706324.py:3: SettingWithCopyWarning:
# ...

# %%
print(df['Benefits'].dtype)
print(df['BasePay'].dtype)
print(df['OvertimePay'].dtype)
print(df['OtherPay'].dtype)
print(df['TotalPay'].dtype)
print(df['TotalPayBenefits'].dtype)
# Out:
# float64
# float64
# float64
# float64
# float64
# float64

# %%
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148645  148646   CAROLYN A WILSON
# 148647  148648     JOANN ANDERSON
# 148648  148649        LEON WALKER
# 148649  148650      ROY I TILLERY
# 148653  148654          JOE LOPEZ
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148645                       HUMAN SERVICES TECHNICIAN       0.00
# ...

# %%
df.describe()
# Out:
#                   Id        BasePay    OvertimePay       OtherPay  \
# count  148648.000000  148648.000000  148648.000000  148648.000000
# mean    74326.110220   66055.452570    5065.821161    3648.761721
# std     42911.633315   42886.182271   11454.266982    8056.655841
# min         1.000000    -166.010000      -0.010000   -7058.590000
# 25%     37163.750000   32797.812500       0.000000       0.000000
# 50%     74326.500000   64862.310000       0.000000     811.205000
# 75%    111488.250000   94611.000000    4657.597500    4236.035000
# max    148654.000000  319275.010000  245131.880000  400184.250000
#
#             Benefits       TotalPay  TotalPayBenefits           Year
# count  148648.000000  148648.000000     148648.000000  148648.000000
# mean    18924.740892   74770.035453      93694.776345    2012.522617
# std     17165.203541   50516.440633      62792.743250       1.117526
# min       -33.890000    -618.130000       -618.130000    2011.000000
# ...

# %%
df.to_csv(r"C:\Users\apano\OneDrive\Documents\power BI FEB 25\excel sheets\task3\finalsalary.csv" ,index= False)
